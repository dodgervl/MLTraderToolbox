# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
rcParams

# %%
path = "/media/dodger/DATA/Projects/Git/MLTraderToolbox/ohlcv_loader/crypto/data/binance/ETH_BTC/"

# %%
print(os.listdir(path))
# Out:
# ['binance_ETH_BTC_2017-07-14_2020-11-08.csv']

# %%
file = 'binance_ETH_BTC_2017-07-14_2020-11-08.csv'
df = pd.read_csv(path+file)

# %%
import mplfinance as mpf

# %%
df.index = pd.to_datetime(df['date'])
del df['date']

# %%
mpf.plot(df[0:100],type='candle',mav=(3,6,9),volume=True)

# %%
mpf.plot(df[0:100], type='candlestick')
